# %%
# Customized script for invista (Converting 3 classes into 2 and save 
# the coordinates of the third class as a list/bounding box)

# INPUT: Semantic label

# Load dependancies
from tkinter import filedialog
from tkinter import * # File dialog
import os
import matplotlib.pyplot as plt # For plotting
import numpy as np
from shutil import copyfile # Copy file
import cv2
import imutils
from skimage.color import rgb2gray
from skimage import img_as_ubyte
import glob # For importing multiple files
import csv

# %%
# User input

# Select file type for import
select_ext = '*.png'
# Define output file type
output_ext = '.png'
# Define suffix
suffix = ''
# Marker class (Specify the value assigned for markers e.g. bg:1, fg:2, marker:3)
marker = 3
# Set foreground class
fg = 1

# %%
# Get user-specific folder selection
# %gui tk
root = Tk()
root.withdraw()
root.update()
folder_selected = filedialog.askdirectory()
root.destroy() # Destroy root window

# %%
# ------------------------------------------------------------------------------------------ #
# Check for Folder

# Export folder name
export_folder_name = 'semantic_label'


# Path for label folder
labelFolder = os.path.join(folder_selected, export_folder_name)
# Export folder
if os.path.exists( labelFolder ):
    print('Output: ##### Export label folder is available. #####')
else:
    os.makedirs( labelFolder )
    print('Output: ##### Create label folder called semantic_label. #####')
# ------------------------------------------------------------------------------------------ #
# Out:
# Output: ##### Export label folder is available. #####

# %%
listFiles = sorted(glob.glob( os.path.join(folder_selected, select_ext)))

# %%
# Preallocate variables
list_obj = []
# Define header for list
header = ['image_id', 'filename', 'object_id', 'centroid_x', 'centroid_y']
list_obj.append(header)
# Define Kernel to remove very small particles which causes erros when obtaining centroids
kernel = np.ones((2,2),np.uint8)
# Set counter
counter = 0
# Total number of images
n_total = len( glob.glob(os.path.join(folder_selected, select_ext)) )

# %%
for ii in range(0, n_total):
    counter = counter + 1
    # Get filename with path
    filename = listFiles[ii]
    # Import as grayscale (for semantic label)
    img = cv2.imread(filename, 0)
    # Obtain filename
    th_fname = os.path.basename(filename) 
    # Get only filename without path or extension
    fname_only = os.path.splitext(th_fname)[0]
    
    ### Extract Markers and save them in a separate image
    # Save centroid of good objects in a list and export it later to csv
    good_obj = img.copy()
    good_obj[good_obj < marker] = 0
    # Convert to binary image
    ret,thresh = cv2.threshold(good_obj,0,255,0)
    
    ### Pre-procesing: Remove objects that are 1x1 pixel small (via erosion)
    erosion = cv2.erode(thresh,kernel,iterations = 1)

    ### Obtain centroids
    # find contours in the cleaned thresholded image
    cnts = cv2.findContours(erosion, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)

    # loop over the contours (resets after each image)
    obj_id = 0
    for c in cnts:
        # Increment index for object id
        obj_id = obj_id + 1
        # compute the center of the contour
        M = cv2.moments(c)
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
        row = [counter, th_fname, obj_id, cX, cY]
        list_obj.append(row)

    
    
    ### Re-assign marker class to object/foreground class (fg)
    new_img = img.copy()
    new_img[new_img == marker] = fg
    
    # Re-assign background from 1 to 0
    if new_img.min() != 0:
        # Shift all classes so that BG becomes 0
        img_shift = new_img - 1
    else:
        # Do nothing
        img_shift = new_img
    
    
    ### Export
    # Construct rename
    rename = fname_only + suffix + output_ext
    # Save image in renamed folder
    cv2.imwrite(os.path.join(labelFolder, rename), img_shift)
    print('Output: ##### Export re-assigned Label: %d out of %d images. #####' % (counter, n_total) ) 
    
print('Output: ##### Exporting files complete. #####')
    

### Export excel file    
# Use 'w' instead of 'wb' for strings
with open(os.path.join(labelFolder, "centroid_good_obj.csv"), 'w') as resultFile:
    wr = csv.writer(resultFile, dialect='excel')
    wr.writerows(list_obj)
# Out:
# Output: ##### Export re-assigned Label: 1 out of 108 images. #####
# Output: ##### Export re-assigned Label: 2 out of 108 images. #####
# Output: ##### Export re-assigned Label: 3 out of 108 images. #####
# Output: ##### Export re-assigned Label: 4 out of 108 images. #####
# Output: ##### Export re-assigned Label: 5 out of 108 images. #####
# Output: ##### Export re-assigned Label: 6 out of 108 images. #####
# Output: ##### Export re-assigned Label: 7 out of 108 images. #####
# Output: ##### Export re-assigned Label: 8 out of 108 images. #####
# Output: ##### Export re-assigned Label: 9 out of 108 images. #####
# Output: ##### Export re-assigned Label: 10 out of 108 images. #####
# Output: ##### Export re-assigned Label: 11 out of 108 images. #####
# Output: ##### Export re-assigned Label: 12 out of 108 images. #####
# Output: ##### Export re-assigned Label: 13 out of 108 images. #####
# Output: ##### Export re-assigned Label: 14 out of 108 images. #####
# Output: ##### Export re-assigned Label: 15 out of 108 images. #####
# Output: ##### Export re-assigned Label: 16 out of 108 images. #####
# Output: ##### Export re-assigned Label: 17 out of 108 images. #####
# Output: ##### Export re-assigned Label: 18 out of 108 images. #####
# Output: ##### Export re-assigned Label: 19 out of 108 images. #####
# Output: ##### Export re-assigned Label: 20 out of 108 images. #####
# Output: ##### Export re-assigned Label: 21 out of 108 images. #####
# Output: ##### Export re-assigned Label: 22 out of 108 images. #####
# Output: ##### Export re-assigned Label: 23 out of 108 images. #####
# Output: ##### Export re-assigned Label: 24 out of 108 images. #####
# Output: ##### Export re-assigned Label: 25 out of 108 images. #####
# Output: ##### Export re-assigned Label: 26 out of 108 images. #####
# Output: ##### Export re-assigned Label: 27 out of 108 images. #####
# Output: ##### Export re-assigned Label: 28 out of 108 images. #####
# Output: ##### Export re-assigned Label: 29 out of 108 images. #####
# Output: ##### Export re-assigned Label: 30 out of 108 images. #####
# Output: ##### Export re-assigned Label: 31 out of 108 images. #####
# Output: ##### Export re-assigned Label: 32 out of 108 images. #####
# Output: ##### Export re-assigned Label: 33 out of 108 images. #####
# Output: ##### Export re-assigned Label: 34 out of 108 images. #####
# Output: ##### Export re-assigned Label: 35 out of 108 images. #####
# Output: ##### Export re-assigned Label: 36 out of 108 images. #####
# Output: ##### Export re-assigned Label: 37 out of 108 images. #####
# Output: ##### Export re-assigned Label: 38 out of 108 images. #####
# Output: ##### Export re-assigned Label: 39 out of 108 images. #####
# Output: ##### Export re-assigned Label: 40 out of 108 images. #####
# Output: ##### Export re-assigned Label: 41 out of 108 images. #####
# Output: ##### Export re-assigned Label: 42 out of 108 images. #####
# Output: ##### Export re-assigned Label: 43 out of 108 images. #####
# Output: ##### Export re-assigned Label: 44 out of 108 images. #####
# Output: ##### Export re-assigned Label: 45 out of 108 images. #####
# Output: ##### Export re-assigned Label: 46 out of 108 images. #####
# Output: ##### Export re-assigned Label: 47 out of 108 images. #####
# Output: ##### Export re-assigned Label: 48 out of 108 images. #####
# Output: ##### Export re-assigned Label: 49 out of 108 images. #####
# Output: ##### Export re-assigned Label: 50 out of 108 images. #####
# Output: ##### Export re-assigned Label: 51 out of 108 images. #####
# Output: ##### Export re-assigned Label: 52 out of 108 images. #####
# Output: ##### Export re-assigned Label: 53 out of 108 images. #####
# Output: ##### Export re-assigned Label: 54 out of 108 images. #####
# Output: ##### Export re-assigned Label: 55 out of 108 images. #####
# Output: ##### Export re-assigned Label: 56 out of 108 images. #####
# Output: ##### Export re-assigned Label: 57 out of 108 images. #####
# Output: ##### Export re-assigned Label: 58 out of 108 images. #####
# Output: ##### Export re-assigned Label: 59 out of 108 images. #####
# Output: ##### Export re-assigned Label: 60 out of 108 images. #####
# Output: ##### Export re-assigned Label: 61 out of 108 images. #####
# Output: ##### Export re-assigned Label: 62 out of 108 images. #####
# Output: ##### Export re-assigned Label: 63 out of 108 images. #####
# Output: ##### Export re-assigned Label: 64 out of 108 images. #####
# Output: ##### Export re-assigned Label: 65 out of 108 images. #####
# Output: ##### Export re-assigned Label: 66 out of 108 images. #####
# Output: ##### Export re-assigned Label: 67 out of 108 images. #####
# Output: ##### Export re-assigned Label: 68 out of 108 images. #####
# Output: ##### Export re-assigned Label: 69 out of 108 images. #####
# Output: ##### Export re-assigned Label: 70 out of 108 images. #####
# Output: ##### Export re-assigned Label: 71 out of 108 images. #####
# Output: ##### Export re-assigned Label: 72 out of 108 images. #####
# Output: ##### Export re-assigned Label: 73 out of 108 images. #####
# Output: ##### Export re-assigned Label: 74 out of 108 images. #####
# Output: ##### Export re-assigned Label: 75 out of 108 images. #####
# Output: ##### Export re-assigned Label: 76 out of 108 images. #####
# Output: ##### Export re-assigned Label: 77 out of 108 images. #####
# Output: ##### Export re-assigned Label: 78 out of 108 images. #####
# Output: ##### Export re-assigned Label: 79 out of 108 images. #####
# Output: ##### Export re-assigned Label: 80 out of 108 images. #####
# Output: ##### Export re-assigned Label: 81 out of 108 images. #####
# Output: ##### Export re-assigned Label: 82 out of 108 images. #####
# Output: ##### Export re-assigned Label: 83 out of 108 images. #####
# Output: ##### Export re-assigned Label: 84 out of 108 images. #####
# Output: ##### Export re-assigned Label: 85 out of 108 images. #####
# Output: ##### Export re-assigned Label: 86 out of 108 images. #####
# Output: ##### Export re-assigned Label: 87 out of 108 images. #####
# Output: ##### Export re-assigned Label: 88 out of 108 images. #####
# Output: ##### Export re-assigned Label: 89 out of 108 images. #####
# Output: ##### Export re-assigned Label: 90 out of 108 images. #####
# Output: ##### Export re-assigned Label: 91 out of 108 images. #####
# Output: ##### Export re-assigned Label: 92 out of 108 images. #####
# Output: ##### Export re-assigned Label: 93 out of 108 images. #####
# Output: ##### Export re-assigned Label: 94 out of 108 images. #####
# Output: ##### Export re-assigned Label: 95 out of 108 images. #####
# Output: ##### Export re-assigned Label: 96 out of 108 images. #####
# Output: ##### Export re-assigned Label: 97 out of 108 images. #####
# Output: ##### Export re-assigned Label: 98 out of 108 images. #####
# Output: ##### Export re-assigned Label: 99 out of 108 images. #####
# Output: ##### Export re-assigned Label: 100 out of 108 images. #####
# Output: ##### Export re-assigned Label: 101 out of 108 images. #####
# Output: ##### Export re-assigned Label: 102 out of 108 images. #####
# Output: ##### Export re-assigned Label: 103 out of 108 images. #####
# Output: ##### Export re-assigned Label: 104 out of 108 images. #####
# Output: ##### Export re-assigned Label: 105 out of 108 images. #####
# Output: ##### Export re-assigned Label: 106 out of 108 images. #####
# Output: ##### Export re-assigned Label: 107 out of 108 images. #####
# Output: ##### Export re-assigned Label: 108 out of 108 images. #####
# Output: ##### Exporting files complete. #####

# %%
### Testing re-assignment of classes
plt.imshow(img_shift)
img_shift.min()
img_shift.max()
