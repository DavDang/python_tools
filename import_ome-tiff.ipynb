# %%
import cv2
import tifffile as tiff
import matplotlib.pyplot as plt

# Raw
raw1 = tiff.imread('temp/Hollowfill_Raw_Z_1_to_10.ome.tiff')
#raw2 = tiff.imread('temp/Z_Stack_Hollowfill_Raw_Z_1_to_10.tiff')
# Mask
mask1 = tiff.imread('temp/HollowFill_Maks_1_10.ome.tiff')
#mask2 = tiff.imread('temp/Z_Stack_Hollowfill_Mask_1_to_10.tiff')
# Out:
# TiffFrame 10: missing required tags
# TiffFrame 10: missing required tags

# %%
raw1.shape
# Out:
# (10, 747, 934, 3)

# %%
mask1.shape
# Out:
# (10, 747, 934, 3)

# %%
raw1.dtype
# Out:
# dtype('uint8')

# %%
mask1.dtype

# %%
mask1_g = mask1[:, :, :, 0]

# %%
mask1_g.shape
# Out:
# (10, 747, 934)

# %%
a1 = mask1_g[1, :, :]

# %%
plt.imshow(a1, cmap='gray')

# %%
raw1_g = raw1[:, : , :, 0]

# %%
b1 = raw1_g[1, :, :]

# %%
plt.imshow(b1, cmap='gray')
